# %%
from cal_utils import *
from scipy.optimize import least_squares, minimize

# %%
file_num = 13
folder = 'geoCal3'
def err_iprobe(iprobe_prm_input, solidCube_prm_input, mode):
    return getError(Prm(iprobe_prm_input[0], 
                        iprobe_prm_input[1], 
                        iprobe_prm_input[2]), 
                    solidCube(solidCube_prm_input[0], 
                              solidCube_prm_input[1], 
                              solidCube_prm_input[2], 
                              solidCube_prm_input[3], 
                              solidCube_prm_input[4], 
                              solidCube_prm_input[5]), 
                    mode, file_num, folder)
    
def err_solidcube(solidCube_prm_input, iprobe_prm_input, mode):
    return getError(Prm(iprobe_prm_input[0], 
                        iprobe_prm_input[1], 
                        iprobe_prm_input[2]), 
                    solidCube(solidCube_prm_input[0], 
                              solidCube_prm_input[1], 
                              solidCube_prm_input[2], 
                              solidCube_prm_input[3], 
                              solidCube_prm_input[4], 
                              solidCube_prm_input[5]), 
                    mode, file_num, folder)

# %%
def iterative_optimization(iprobe_prm_input, solidCube_prm_input, 
                           tol=1e-6, max_iter=1000):
    prev_error = np.inf
    for iteration in range(max_iter):
        result_iprobe = minimize(fun=err_iprobe, 
                                 x0=iprobe_prm_input, 
                                 args=(solidCube_prm_input, 'scalar'), 
                                 method='L-BFGS-B', 
                                 bounds=[(53.5, 73.5), 
                                         (67.0, 87.0), 
                                         (-87.0, -67.0)], 
                                 tol=tol,
                                 options={'maxiter': max_iter, 'disp': False})
        iprobe_prm_input = result_iprobe.x
        
        # result_iprobe = least_squares(main1, 
        #                               iprobe_prm_input, 
        #                               args=(solidCube_prm_input, 'vector'), 
        #                               method='trf', 
        #                               bounds=([60.0, 70.0, -80.0], 
        #                                       [70.0, 80.0, -70.0]), 
        #                               ftol=tol, 
        #                               tr_options={'verbosity': 1, 'max_iter': 1000}, 
        #                               verbose=1, 
        #                               max_nfev=300)
        # iprobe_prm_input = result_iprobe.x
        
        # current_error = main1(iprobe_prm_input, solidCube_prm_input, 'scalar')
        # if abs(prev_error - current_error) < tol:
        #     print(f"Iteration {iteration+1}, Error: {current_error:.8f}")
        #     print("Converged.")
        #     break
        
        result_solidCube = least_squares(fun=err_solidcube, 
                                         x0=solidCube_prm_input, 
                                         args=(iprobe_prm_input, 'vector'), 
                                         ftol=tol, 
                                         # tr_options={'verbosity': 1, 'max_iter': 2000}, 
                                         verbose=1, 
                                         max_nfev=max_iter)
        solidCube_prm_input = result_solidCube.x
        
        # result_solidCube = minimize(main2, 
        #                             solidCube_prm_input, 
        #                             args=(iprobe_prm_input, 'scalar'), 
        #                             method='L-BFGS-B', 
        #                             tol=tol,
        #                             options={'maxiter': 2000, 'disp': False})
        # solidCube_prm_input = result_solidCube.x
        
        current_error = err_iprobe(iprobe_prm_input, solidCube_prm_input, 'scalar')
        print(f"Iteration {iteration+1}, Error: {current_error:.8f}")
        if abs(prev_error - current_error) < tol:
            print("Converged.")
            break
        prev_error = current_error
    
    return iprobe_prm_input, solidCube_prm_input, current_error

# %%
# iprobe_prm_input = [63.5, 77.0, -77.0]
# solidCube_prm_input = [-2.2266e-03, 6.3928e-02, -5.1277e-05, 
#                        5.4682e+00, 7.0481e-04, 4.8222e-04]
iprobe_prm_input = [66.20844612, 74.07940723, -77.77190349]
solidCube_prm_input = [5.75713355e-03, 1.65454347e-01, -2.51927934e-03, 
                       5.47618023e+00, 6.33467621e-02, -4.00017302e-04]

print(f"Before calibration: {err_iprobe(iprobe_prm_input, solidCube_prm_input, 'scalar')}")
final_iprobe_prm, final_solidCube_prm, final_error = iterative_optimization(iprobe_prm_input, solidCube_prm_input)

print("\nFinal optimized parameters:")
print(f"iProbe Parameters: [{final_iprobe_prm[0]}, {final_iprobe_prm[1]}, {final_iprobe_prm[2]}]")
print(f"SolidCube Parameters: [{final_solidCube_prm[0]}, {final_solidCube_prm[1]}, {final_solidCube_prm[2]}, {final_solidCube_prm[3]}, {final_solidCube_prm[4]}, {final_solidCube_prm[5]}]")
print("Final Error:", final_error)
# Out:
# Before calibration: 0.7471810259117603
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7359e-01, final cost 3.7359e-01, first-order optimality 1.84e-01.
# Iteration 1, Error: 0.74717897
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7359e-01, final cost 3.7359e-01, first-order optimality 1.84e-01.
# Iteration 2, Error: 0.74717691
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7359e-01, final cost 3.7359e-01, first-order optimality 1.84e-01.
# Iteration 3, Error: 0.74717485
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7359e-01, final cost 3.7359e-01, first-order optimality 1.84e-01.
# Iteration 4, Error: 0.74717280
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7359e-01, final cost 3.7359e-01, first-order optimality 1.84e-01.
# Iteration 5, Error: 0.74717074
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7359e-01, final cost 3.7358e-01, first-order optimality 1.84e-01.
# Iteration 6, Error: 0.74716868
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7358e-01, final cost 3.7358e-01, first-order optimality 1.84e-01.
# Iteration 7, Error: 0.74716663
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7358e-01, final cost 3.7358e-01, first-order optimality 1.84e-01.
# Iteration 8, Error: 0.74716457
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7358e-01, final cost 3.7358e-01, first-order optimality 1.84e-01.
# Iteration 9, Error: 0.74716252
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7358e-01, final cost 3.7358e-01, first-order optimality 1.84e-01.
# Iteration 10, Error: 0.74716046
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7358e-01, final cost 3.7358e-01, first-order optimality 1.84e-01.
# Iteration 11, Error: 0.74715841
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7358e-01, final cost 3.7358e-01, first-order optimality 1.84e-01.
# Iteration 12, Error: 0.74715635
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7358e-01, final cost 3.7358e-01, first-order optimality 1.84e-01.
# Iteration 13, Error: 0.74715430
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7358e-01, final cost 3.7358e-01, first-order optimality 1.84e-01.
# Iteration 14, Error: 0.74715224
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7358e-01, final cost 3.7358e-01, first-order optimality 1.84e-01.
# Iteration 15, Error: 0.74715019
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7358e-01, final cost 3.7357e-01, first-order optimality 1.84e-01.
# Iteration 16, Error: 0.74714814
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7357e-01, final cost 3.7357e-01, first-order optimality 1.84e-01.
# Iteration 17, Error: 0.74714608
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7357e-01, final cost 3.7357e-01, first-order optimality 1.84e-01.
# Iteration 18, Error: 0.74714403
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7357e-01, final cost 3.7357e-01, first-order optimality 1.84e-01.
# Iteration 19, Error: 0.74714198
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7357e-01, final cost 3.7357e-01, first-order optimality 1.84e-01.
# Iteration 20, Error: 0.74713993
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7357e-01, final cost 3.7357e-01, first-order optimality 1.84e-01.
# Iteration 21, Error: 0.74713788
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7357e-01, final cost 3.7357e-01, first-order optimality 1.84e-01.
# Iteration 22, Error: 0.74713582
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7357e-01, final cost 3.7357e-01, first-order optimality 1.84e-01.
# Iteration 23, Error: 0.74713377
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7357e-01, final cost 3.7357e-01, first-order optimality 1.84e-01.
# Iteration 24, Error: 0.74713172
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7357e-01, final cost 3.7356e-01, first-order optimality 1.84e-01.
# Iteration 25, Error: 0.74712967
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7356e-01, final cost 3.7356e-01, first-order optimality 1.84e-01.
# Iteration 26, Error: 0.74712762
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7356e-01, final cost 3.7356e-01, first-order optimality 1.84e-01.
# Iteration 27, Error: 0.74712557
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7356e-01, final cost 3.7356e-01, first-order optimality 1.84e-01.
# Iteration 28, Error: 0.74712352
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7356e-01, final cost 3.7356e-01, first-order optimality 1.84e-01.
# Iteration 29, Error: 0.74712147
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7356e-01, final cost 3.7356e-01, first-order optimality 1.84e-01.
# Iteration 30, Error: 0.74711942
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7356e-01, final cost 3.7356e-01, first-order optimality 1.84e-01.
# Iteration 31, Error: 0.74711738
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7356e-01, final cost 3.7356e-01, first-order optimality 1.84e-01.
# Iteration 32, Error: 0.74711533
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7356e-01, final cost 3.7356e-01, first-order optimality 1.84e-01.
# Iteration 33, Error: 0.74711328
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7356e-01, final cost 3.7356e-01, first-order optimality 1.84e-01.
# Iteration 34, Error: 0.74711123
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7356e-01, final cost 3.7355e-01, first-order optimality 1.84e-01.
# Iteration 35, Error: 0.74710918
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7355e-01, final cost 3.7355e-01, first-order optimality 1.84e-01.
# Iteration 36, Error: 0.74710714
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7355e-01, final cost 3.7355e-01, first-order optimality 1.84e-01.
# Iteration 37, Error: 0.74710509
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7355e-01, final cost 3.7355e-01, first-order optimality 1.84e-01.
# Iteration 38, Error: 0.74710304
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7355e-01, final cost 3.7355e-01, first-order optimality 1.84e-01.
# Iteration 39, Error: 0.74710100
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7355e-01, final cost 3.7355e-01, first-order optimality 1.84e-01.
# Iteration 40, Error: 0.74709895
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7355e-01, final cost 3.7355e-01, first-order optimality 1.84e-01.
# Iteration 41, Error: 0.74709691
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7355e-01, final cost 3.7355e-01, first-order optimality 1.84e-01.
# Iteration 42, Error: 0.74709486
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7355e-01, final cost 3.7355e-01, first-order optimality 1.84e-01.
# Iteration 43, Error: 0.74709282
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7355e-01, final cost 3.
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7291e-01, final cost 3.7291e-01, first-order optimality 1.84e-01.
# Iteration 698, Error: 0.74581634
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7291e-01, final cost 3.7291e-01, first-order optimality 1.84e-01.
# Iteration 699, Error: 0.74581449
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7291e-01, final cost 3.7291e-01, first-order optimality 1.84e-01.
# Iteration 700, Error: 0.74581263
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7291e-01, final cost 3.7291e-01, first-order optimality 1.84e-01.
# Iteration 701, Error: 0.74581077
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7291e-01, final cost 3.7290e-01, first-order optimality 1.84e-01.
# Iteration 702, Error: 0.74580891
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7290e-01, final cost 3.7290e-01, first-order optimality 1.84e-01.
# Iteration 703, Error: 0.74580706
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7290e-01, final cost 3.7290e-01, first-order optimality 1.84e-01.
# Iteration 704, Error: 0.74580520
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7290e-01, final cost 3.7290e-01, first-order optimality 1.84e-01.
# Iteration 705, Error: 0.74580334
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7290e-01, final cost 3.7290e-01, first-order optimality 1.84e-01.
# Iteration 706, Error: 0.74580149
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7290e-01, final cost 3.7290e-01, first-order optimality 1.84e-01.
# Iteration 707, Error: 0.74579963
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7290e-01, final cost 3.7290e-01, first-order optimality 1.84e-01.
# Iteration 708, Error: 0.74579778
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7290e-01, final cost 3.7290e-01, first-order optimality 1.84e-01.
# Iteration 709, Error: 0.74579592
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7290e-01, final cost 3.7290e-01, first-order optimality 1.84e-01.
# Iteration 710, Error: 0.74579406
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7290e-01, final cost 3.7290e-01, first-order optimality 1.84e-01.
# Iteration 711, Error: 0.74579221
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7290e-01, final cost 3.7290e-01, first-order optimality 1.84e-01.
# Iteration 712, Error: 0.74579036
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7290e-01, final cost 3.7289e-01, first-order optimality 1.84e-01.
# Iteration 713, Error: 0.74578850
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7289e-01, final cost 3.7289e-01, first-order optimality 1.84e-01.
# Iteration 714, Error: 0.74578665
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7289e-01, final cost 3.7289e-01, first-order optimality 1.84e-01.
# Iteration 715, Error: 0.74578479
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7289e-01, final cost 3.7289e-01, first-order optimality 1.84e-01.
# Iteration 716, Error: 0.74578294
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7289e-01, final cost 3.7289e-01, first-order optimality 1.84e-01.
# Iteration 717, Error: 0.74578109
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7289e-01, final cost 3.7289e-01, first-order optimality 1.84e-01.
# Iteration 718, Error: 0.74577923
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7289e-01, final cost 3.7289e-01, first-order optimality 1.84e-01.
# Iteration 719, Error: 0.74577738
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7289e-01, final cost 3.7289e-01, first-order optimality 1.84e-01.
# Iteration 720, Error: 0.74577553
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7289e-01, final cost 3.7289e-01, first-order optimality 1.84e-01.
# Iteration 721, Error: 0.74577368
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7289e-01, final cost 3.7289e-01, first-order optimality 1.84e-01.
# Iteration 722, Error: 0.74577182
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7289e-01, final cost 3.7288e-01, first-order optimality 1.84e-01.
# Iteration 723, Error: 0.74576997
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7288e-01, final cost 3.7288e-01, first-order optimality 1.84e-01.
# Iteration 724, Error: 0.74576812
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7288e-01, final cost 3.7288e-01, first-order optimality 1.84e-01.
# Iteration 725, Error: 0.74576627
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7288e-01, final cost 3.7288e-01, first-order optimality 1.84e-01.
# Iteration 726, Error: 0.74576442
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7288e-01, final cost 3.7288e-01, first-order optimality 1.84e-01.
# Iteration 727, Error: 0.74576257
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7288e-01, final cost 3.7288e-01, first-order optimality 1.84e-01.
# Iteration 728, Error: 0.74576072
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7288e-01, final cost 3.7288e-01, first-order optimality 1.84e-01.
# Iteration 729, Error: 0.74575887
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7288e-01, final cost 3.7288e-01, first-order optimality 1.84e-01.
# Iteration 730, Error: 0.74575702
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7288e-01, final cost 3.7288e-01, first-order optimality 1.84e-01.
# Iteration 731, Error: 0.74575517
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7288e-01, final cost 3.7288e-01, first-order optimality 1.84e-01.
# Iteration 732, Error: 0.74575332
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7288e-01, final cost 3.7288e-01, first-order optimality 1.84e-01.
# Iteration 733, Error: 0.74575147
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7288e-01, final cost 3.7287e-01, first-order optimality 1.84e-01.
# Iteration 734, Error: 0.74574962
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7287e-01, final cost 3.7287e-01, first-order optimality 1.84e-01.
# Iteration 735, Error: 0.74574777
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7287e-01, final cost 3.7287e-01, first-order optimality 1.84e-01.
# Iteration 736, Error: 0.74574593
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7287e-01, final cost 3.7287e-01, first-order optimality 1.84e-01.
# Iteration 737, Error: 0.74574408
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7287e-01, final cost 3.7287e-01, first-order optimality 1.84e-01.
# Iteration 738, Error: 0.74574223
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7287e-01, final cost 3.7287e-01, first-order optimality 1.84e-01.
# Iteration 739, Error: 0.74574038
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7287e-01, final cost 3.7287e-01, first-order optimality 1.84e-01.
# Iteration 740, Error: 0.74573853
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7287e-01, final cost 3.7287e-01, first-order optimality 1.84e-01.
# Iteration 741, Error: 0.74573669
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7287e-01, final cost 3.7287e-01, first-order optimality 1.84e-01.
# Iteration 742, Error: 0.74573484
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7287e-01, final cost 3.7287e-01, first-order optimality 1.84e-01.
# Iteration 743, Error: 0.74573299
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7287e-01, final cost 3.7287e-01, first-order optimality 1.84e-01.
# Iteration 744, Error: 0.74573115
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7287e-01, final cost 3.7286e-01, first-order optimality 1.84e-01.
# Iteration 745, Error: 0.74572930
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7286e-01, final cost 3.7286e-01, first-order optimality 1.84e-01.
# Iteration 746, Error: 0.74572746
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7286e-01, final cost 3.7286e-01, first-order optimality 1.84e-01.
# Iteration 747, Error: 0.74572561
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7286e-01, final cost 3.7286e-01, first-order optimality 1.84e-01.
# Iteration 748, Error: 0.74572377
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7286e-01, final cost 3.7286e-01, first-order optimality 1.84e-01.
# Iteration 749, Error: 0.74572192
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7286e-01, final cost 3.7286e-01, first-order optimality 1.84e-01.
# Iteration 750, Error: 0.74572008
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7286e-01, final cost 3.7286e-01, first-order optimality 1.84e-01.
# Iteration 751, Error: 0.74571823
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7286e-01, final cost 3.7286e-01, first-order optimality 1.84e-01.
# Iteration 752, Error: 0.74571639
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.7286e-01, final cost 3.7286e-01, first-order optimality 1.84e-01.
# Iteration 753, Error: 0.74571454
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 3.7286e-01, final cost 3.7286e-01, first-order optimality 1.60e-01.
# Iteration 754, Error: 0.74571409
# Converged.
#
# Final optimized parameters:
# iProbe Parameters: [66.20848813776877, 74.07944720546551, -77.77180668329676]]
# SolidCube Parameters: [0.006088377324876562, 0.16975562983065898, -0.002661611514096111, 5.4765105771127836, 0.06394317137365886, -0.0004192672503799672]
# Final Error: 0.74571408961852

# %%
# test
iprobe_prm_input = [63.5, 77, -77]
solidCube_prm_input = [0, 0, 0, 0, 0, 0]
print(f"Before calibration: {err_iprobe(iprobe_prm_input, solidCube_prm_input, 'vector')}")

iprobe_prm_input = [66.20844612, 74.07940723, -77.77190349]
solidCube_prm_input = [5.75713355e-03, 1.65454347e-01, -2.51927934e-03, 
                       5.47618023e+00, 6.33467621e-02, -4.00017302e-04]
print(f"After calibration: {err_iprobe(iprobe_prm_input, solidCube_prm_input, 'vector')}")
# Out:
# After calibration: [0.36082829 0.70891104 0.33827372]
# Before calibration: [0.94955135 2.92931481 2.44037232]
